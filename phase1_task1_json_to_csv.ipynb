# %%
import pandas as pd
import requests
import csv

response = requests.get('https://data.binance.com/api/v3/ticker/24hr')
data = response.json()

df=pd.DataFrame(data)
df.to_csv('binance_data.csv',index=False)
pd.read_csv('binance_data.csv')
# Out:
#          symbol   priceChange  priceChangePercent  weightedAvgPrice  \
# 0        ETHBTC  2.200000e-04               0.367          0.060108
# 1        LTCBTC  2.800000e-05               1.151          0.002446
# 2        BNBBTC  4.400000e-05               0.555          0.007960
# 3        NEOBTC  1.000000e-07               0.036          0.000278
# 4       QTUMETH -1.200000e-05              -0.868          0.001381
# ...         ...           ...                 ...               ...
# 2297    ARKUSDT -1.670000e-02              -3.306          0.490923
# 2298  CREAMUSDT -4.370000e+00             -20.421         18.403249
# 2299    GFTUSDT  4.000000e-05               0.195          0.020546
# 2300     IQUSDT -2.700000e-04              -5.488          0.004818
# 2301    USDTVAI  6.000000e-03               0.596          1.012824
#
#       prevClosePrice  lastPrice     lastQty   bidPrice       bidQty  \
# 0           0.059960   0.060180      3.1515   0.060180       2.5417
# ...
